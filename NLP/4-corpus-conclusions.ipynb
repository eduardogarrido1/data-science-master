# %% [markdown]
# # Módulo 4: Reporte de métricas y conclusiones

# %% [markdown]
# En este momento, se rescatarán y se estudiarán los resultados obtenidos por los modelos. Para eso importaremos el DataFrame creado en la parte de modelado con el reporte de las métricas calculadas.

# %%
# En primer lugar, hacemos los imports necesarios
import pandas as pd

# Luego importamos el Reporte de Métricas de la etapa anterior
dfmetrics = pd.read_csv('./MusicalInstrumentsMetrics.csv')

# Agrupamos por modelo
dfmetrics.groupby(['Model','Category']).mean()
# Out:
#                                  Accuracy  Precision    Recall  F1 Score
# Model                  Category
# LogisticRegression     Test      0.787053   0.793840  0.940674  0.861042
#                        Train     0.791421   0.796264  0.942758  0.863341
# RandomForestClassifier Test      0.701970   0.701806  0.999938  0.824757
#                        Train     0.699511   0.699320  0.999972  0.823049

# %% [markdown]
# ### Conclusiones Finales
#
# Este proyecto de Supervised Sentiment Analysis se compuso de 4 partes: Descarga y exploracion del corpus, Preprocesamiento del corpus, Modelado del corpus y Reporte de métricas. En cada una de las partes se ejecutaron procesos importantes y se descubrieron cosas relevantes. Las observaciones más marcadas serán descritas a continuación:
#
# - Descarga y exploración del corpus:
# En esta etapa estudiamos las informaciones del corpus. Notamos que estaba bastante desbalanceado en el sentido de que había demasiadas reviews de calificación 5 en comparación a las demás calificaciones. Por eso tomamos la decisión de tratarlo como un problema de clasificación binaria donde cualquier calificación inferior a 5 sería considerada como calificación negativa. Aún así el corpus estaba desbalanceado, sin embargo, ya era mucho más cómodo de trabajar.
#
# - Preprocesamiento del corpus:
# En esta etapa logramos reestructurar el corpus con el objetivo de que se le pudiese extraer todo el valor posible en la parte de modelado. Eliminamos los signos de puntuación, caracteres no alfabéticos y stopwords. y logramos conseguir un corpus que podía ser eficientemente explotado por los modelos posteriores.
#
# - Modelado del corpus:
# En esta etapa se trabajaron dos modelos de Machine Learning: Regresión Logística y Clasificación Binaria con Bosques Aleatorios. Se calcularon los mejores hiperparámetros para cada uno y pudimos obtener resultados bastante decentes, todo sin caer en overfitting.
#
# - Reporte de métricas:
# Habiendo visto las métricas calculadas para los modelos, podemos extraer conclusiones interesantes. Algunas métricas como el Accuracy o Precision presentaron resultados ligeramente mejores para el modelo de Regresión Logística. Mientras que el Recall presentó resultados ligeramente mejores para el modelo de Clasificación Binaria con Bosques Aleatorios. Esto quiere decir que la selección del mejor modelo dependerá del problema que se este tratando en el momento... En este momento, como no tenemos un objetivo específico, nos dedicaremos a decidir como mejor modelo la Regresión Logística, pues tiene un Accuracy, Precision y F1 Score ligeramente más altos.
